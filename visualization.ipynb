# %%
# %matplotlib inline

# %%
import json

# %%
import matplotlib.pyplot as plt

# %%
results = []

with open('/homes/gws/gezhang/BERT-pytorch/temp_md_8/results.txt','r') as f:
    for l in f:
        results.append(json.loads(l))

# results[0]

accuracis = [r["accuracy"] for r in results]

plt.plot(accuracis)

# %%
results = []

with open('/homes/gws/gezhang/BERT-pytorch/temp_md_7/results.txt','r') as f:
    for l in f:
        results.append(json.loads(l))

# results[0]

accuracis = [r["accuracy"] for r in results]

plt.plot(accuracis)

# %%
results = []

with open('/homes/gws/gezhang/BERT-pytorch/delete_3/results.txt','r') as f:
    for l in f:
        results.append(json.loads(l))

# results[0]

accuracis = [r["accuracy"] for r in results]

plt.plot(accuracis)
